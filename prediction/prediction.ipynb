# %%
import pandas as pd
import numpy as np

# %%
test= pd.read_csv("../data/Test.csv")
test.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# ...

# %%
test.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
test['Item_Weight']=test['Item_Weight'].fillna(test.groupby('Item_Identifier')['Item_Weight'].transform('mean'))
test.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                    20
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
test['Item_Weight']=test['Item_Weight'].fillna(test.groupby('Item_Type')['Item_Weight'].transform('mean'))
test.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
pd.crosstab(test.Outlet_Size,test.Outlet_Location_Type)
# Out:
# Outlet_Location_Type  Tier 1  Tier 2  Tier 3
# Outlet_Size
# High                       0       0     621
# Medium                   620       0    1242
# Small                    972     620       0

# %%
dic= {"Tier 2":"Small"}
s= test["Outlet_Location_Type"].map(dic)

test.Outlet_Size = test.Outlet_Size.combine_first(s)

test.Outlet_Size.value_counts()
# Out:
# Small     2828
# Medium    1862
# High       621
# Name: Outlet_Size, dtype: int64

# %%
test.isnull().sum()
# Out:
# Item_Identifier                0
# Item_Weight                    0
# Item_Fat_Content               0
# Item_Visibility                0
# Item_Type                      0
# Item_MRP                       0
# Outlet_Identifier              0
# Outlet_Establishment_Year      0
# Outlet_Size                  370
# Outlet_Location_Type           0
# Outlet_Type                    0
# dtype: int64

# %%
pd.crosstab(test.Outlet_Size,test.Outlet_Type)
# Out:
# Outlet_Type  Grocery Store  Supermarket Type1  Supermarket Type2  \
# Outlet_Size
# High                     0                621                  0
# Medium                   0                620                618
# Small                  352               2476                  0
#
# Outlet_Type  Supermarket Type3
# Outlet_Size
# High                         0
# Medium                     624
# Small                        0

# %%
dic = {'Grocery Store':'Small'}
s = test.Outlet_Type.map(dic)
test.Outlet_Size= test.Outlet_Size.combine_first(s)
test.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# dtype: int64

# %%
## Outlet_Years

test["Outlet_Years"]= test["Outlet_Establishment_Year"].apply(lambda x: 2021-x)
test.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38       13.600          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007       Small
# 2  241.7538            OUT010                       1998       Small
# 3  155.0340            OUT017                       2007       Small
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type  Outlet_Years
# ...

# %%
# Item_Type_New

def get_first_two_char(obj):
    first_two= obj[:2]
    if first_two== "FD":
        return "Food"
    elif first_two =="DR":
        return "Drinks"
    else:
        return "Non-Consumable"

test["Item_Type_New"]= test["Item_Identifier"].apply(get_first_two_char)

# %%
test.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38       13.600          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007       Small
# 2  241.7538            OUT010                       1998       Small
# 3  155.0340            OUT017                       2007       Small
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type  Outlet_Years   Item_Type_New
# ...

# %%
test.Item_Fat_Content.unique()
# Out:
# array(['Low Fat', 'reg', 'Regular', 'LF', 'low fat'], dtype=object)

# %%
test["Item_Fat_Content"]= test["Item_Fat_Content"].map(
    {"low fat":"Low Fat",
     "reg":"Regular Fat",
     "LF":"Low Fat",
     "Regular":"Regular Fat",
     "Low Fat":"Low Fat"})
test.Item_Fat_Content.unique()
# Out:
# array(['Low Fat', 'Regular Fat'], dtype=object)

# %%
imputed_test= test.copy()

# %% [markdown]
# ### features that to be label encoded
# 1. Item_Fat_Content
# 2. Outlet_Identifier
# 3. Outlet_Size
# 4. Outlet_Location_Type
# 5. Outlet_Type
# 6. Item_Type
# 7. Item_Type_New

# %%
import pickle

labels= ["Item_Fat_Content","Outlet_Size","Outlet_Location_Type","Outlet_Type","Item_Type"]

for label in labels:
    try:
        filename= "le_" + label + ".sav"
        encoder = pickle.load(open("../cleaning/Label_encoder/"+filename,"rb"))
        test[label]= encoder.transform(test[label])
    except Exception as e:
        raise e

# %%
test.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0           FDW58       20.750                 0         0.007565         13
# 1           FDW14        8.300                 2         0.038428          4
# 2           NCN55       14.600                 0         0.099575         11
# 3           FDQ58        7.315                 0         0.015388         13
# 4           FDY38       13.600                 2         0.118599          4
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  107.8622            OUT049                       1999            1
# 1   87.3198            OUT017                       2007            2
# 2  241.7538            OUT010                       1998            2
# 3  155.0340            OUT017                       2007            2
# 4  234.2300            OUT027                       1985            1
#
#    Outlet_Location_Type  Outlet_Type  Outlet_Years   Item_Type_New
# ...

# %%
test= test.drop(columns=["Item_Identifier","Outlet_Establishment_Year","Item_Type_New", ],axis= 1) 
# droping ITem_Type_New as a part of getting better performence(model tuning)
test.head()
# Out:
#    Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0       20.750                 0         0.007565         13  107.8622
# 1        8.300                 2         0.038428          4   87.3198
# 2       14.600                 0         0.099575         11  241.7538
# 3        7.315                 0         0.015388         13  155.0340
# 4       13.600                 2         0.118599          4  234.2300
#
#   Outlet_Identifier  Outlet_Size  Outlet_Location_Type  Outlet_Type  \
# 0            OUT049            1                     0            1
# 1            OUT017            2                     1            1
# 2            OUT010            2                     2            0
# 3            OUT017            2                     1            1
# 4            OUT027            1                     2            3
#
#    Outlet_Years
# 0            22
# 1            14
# 2            23
# 3            14
# 4            36

# %% [markdown]
# ## Prediction

# %% [markdown]
# ### scaling

# %%
with open("../model_training/scaler.sav","rb") as f:
    scaler = pickle.load(f)

# %%
test= scaler.transform(test)
# Out:
# C:\Users\Adesh Kumar\anaconda3\envs\bigmart\lib\site-packages\sklearn\base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - Outlet_Identifier
# Feature names must be in the same order as they were in fit.
#
#   warnings.warn(message, FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\ADESHK~1\AppData\Local\Temp/ipykernel_6336/3692153482.py in <module>
# ----> 1 test= scaler.transform(test)
#
# ~\anaconda3\envs\bigmart\lib\site-packages\sklearn\preprocessing\_data.py in transform(self, X, copy)
#     971
#     972         copy = copy if copy is not None else self.copy
# --> 973         X = self._validate_data(
#     974             X,
#     975             reset=False,
#
# ...

# %% [markdown]
# ### loading model

# %%
with open("../model_training/model.sav","rb") as f:
    model = pickle.load(f)

# %%
predicted_sales= model.predict(test)

# %%
imputed_test["Predicted_Sales"]= predicted_sales
imputed_test.head(10)

# %%
imputed_test.to_csv("predicted_file.csv",index=False)
